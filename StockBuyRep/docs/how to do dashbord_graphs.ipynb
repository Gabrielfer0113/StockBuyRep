# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json

# %%
with open("C:\\Users\\Leo\\Documents\\GitHub\\StockBuyRep\\configuration\\davik_report.json", 'r') as file:
    data = json.load(file)
davik = pd.DataFrame(data['report'])
davik
# Out:
#    bitola material norma dimensao  milimetros fabricacao  urgente  atrasado  \
# 0       Q        A     D        1        3000  TREFILADO        0         0
# 1       R        A     D       1"        3000  TREFILADO        1         0
# 2       S        A     G    1-1/2        6000  TREFILADO        0         0
# 3       Q        A     D    1-1/4        6000  TREFILADO        0         0
# 4       R        A     G    1-1/4        6000   LAMINADO        1         0
# 5       R        A     D    1-3/4        3000  TREFILADO        1         0
# 6       R        A     D    1-3/8        6000  TREFILADO        1         0
# 7       R        A     D    15/16        6000  TREFILADO        0         0
# 8       Q        A     D       2"        3000  TREFILADO        0         0
# 9       R        A     D       2"        6000  TREFILADO        1         0
# 10      R        A     D    2-1/2        6000  TREFILADO        1         0
# ...

# %% [markdown]
# ___
# **Top 5 materiais**
# Grafico de barras dos materiais mais solicitados

# %%
mp_agrop_quilos = davik[['bitola','material','norma','dimensao','milimetros','fabricacao','quilos']].groupby(['bitola','material','norma','dimensao','fabricacao']).sum()

mp_agrop_quilos.reset_index(inplace=True)
materiais_dict = mp_agrop_quilos.to_dict(orient='list')

materiais_dict = pd.DataFrame(mp_agrop_quilos)
materiais_dict = materiais_dict.sort_values(by='quilos', ascending=False )
materiais_dict
# Out:
#    bitola material norma dimensao fabricacao  milimetros  quilos
# 21      R        A     G    6-1/2   LAMINADO        3000     584
# 4       R        A    AC   3-1/2"   LAMINADO        6000     339
# 5       R        A    AC    4-3/4   LAMINADO        3000     312
# 20      R        A     G       3"   LAMINADO        6000     249
# 12      R        A     D    2-1/2  TREFILADO        6000     173
# 19      R        A     G    2-1/2  TREFILADO        6000     173
# 15      R        A     D    3-1/2   LAMINADO        3000     170
# 13      R        A     D    2-1/4  TREFILADO        6000     140
# 14      R        A     D       3"  TREFILADO        3000     125
# 11      R        A     D       2"  TREFILADO        6000     111
# 18      R        A     G    1-3/4   LAMINADO        6000      85
# 2       Q        A     D       2"  TREFILADO        3000      71
# 29      S        A     G    1-1/2  TREFILADO        6000      69
# ...

# %%
top5 = materiais_dict.head(5)[['bitola', 'material', 'norma', 'dimensao', 'fabricacao', 'quilos']]
top5
# Out:
#    bitola material norma dimensao fabricacao  quilos
# 21      R        A     G    6-1/2   LAMINADO     584
# 4       R        A    AC   3-1/2"   LAMINADO     339
# 5       R        A    AC    4-3/4   LAMINADO     312
# 20      R        A     G       3"   LAMINADO     249
# 12      R        A     D    2-1/2  TREFILADO     173

# %%
top5_names = top5['bitola'] + top5['material'] + top5['norma'] + top5['dimensao']
print(list(top5_names))
# Out:
# ['RAG6-1/2', 'RAAC3-1/2"', 'RAAC4-3/4', 'RAG3"', 'RAD2-1/2']

# %%
top5_values = list(top5['quilos'])
top5_values
# Out:
# [584, 339, 312, 249, 173]

# %%
fig, ax = plt.subplots()

names = top5_names
values = top5_values
bar_labels = ['blue']
bar_colors = ['tab:blue']

ax.bar(names, values, label=bar_labels, color=bar_colors)

ax.set_ylabel('quilos')
ax.set_title('Top 5 maiores quantidades')
# ax.legend(title='Fruit color')

plt.show()

# %% [markdown]
# ___
# **Normas mais solicitadas**
# Grafico de pizza (pie)

# %%
# mp_agrop_normas = davik['norma'].value_counts()
mp_agrop_normas = pd.DataFrame(mp_agrop_quilos[['norma','quilos']].groupby('norma').sum().reset_index())
mp_agrop_normas

norma_names = list(mp_agrop_normas['norma'])
norma_values = list(mp_agrop_normas['quilos'])
# norma_names = dict(mp_agrop_normas).keys()
# norma_values = dict(mp_agrop_normas).values()
# print(mp_agrop_normas)

# %%
# # Dados
# norma_names = ['D', 'G', 'AC', 'J', 'Q', 'L', 'C']
# norma_values = [16, 7, 3, 2, 2, 1, 1]

# Cores
# colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99', '#c2c2f0', '#ffb3e6', '#c2f0c2']

# Crie um gráfico de pizza simples
plt.pie(norma_values, labels=norma_names, autopct='%1.1f%%', startangle=45)

# Defina o título do gráfico
plt.title("Simplified Pie Chart")
plt.legend(norma_names, loc="center left", bbox_to_anchor=(1, 0.5))
# Exiba o gráfico de pizza
plt.show()

# %% [markdown]
# ___
# **Bitola mais solicitada**
# grafico de pizza

# %%
mp_agrop_bitola = pd.DataFrame(mp_agrop_quilos[['bitola','quilos']].groupby('bitola').sum().reset_index())
mp_agrop_bitola

bitola_names = list(mp_agrop_normas['bitola'])
bitola_values = list(mp_agrop_normas['quilos'])

print(bitola_names, bitola_values)
# print(mp_agrop_bitola)
# bitola_names = dict(mp_agrop_bitola).keys()
# bitola_values = dict(mp_agrop_bitola).values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Leo\AppData\Local\Programs\Python\Python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bitola'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-1c6af0b63611> in <module>
# ...

# %%
# Crie um gráfico de pizza simples
plt.pie(bitola_values, labels=bitola_names, autopct='%1.1f%%', startangle=45)

# Defina o título do gráfico
plt.title("Simplified Pie Chart")
plt.legend(bitola_names, loc="center left", bbox_to_anchor=(1, 0.5))
# Exiba o gráfico de pizza
plt.show()

# %% [markdown]
# ___
# **Tipos de fabricação**
# Grafico de pizza

# %%
mp_agrop_fabricacao = davik['fabricacao'].value_counts()
print(mp_agrop_fabricacao)
fabricacao_names = dict(mp_agrop_fabricacao).keys()
fabricacao_values = dict(mp_agrop_fabricacao).values()
# Out:
# TREFILADO    24
# LAMINADO      8
# Name: fabricacao, dtype: int64

# %%
# Crie um gráfico de pizza simples
plt.pie(fabricacao_values, labels=fabricacao_names, autopct='%1.1f%%', startangle=45)

# Defina o título do gráfico
plt.title("Simplified Pie Chart")
plt.legend(fabricacao_names, loc="center left", bbox_to_anchor=(1, 0.5))
# Exiba o gráfico de pizza
plt.show()

# %% [markdown]
# ___
# **Exemplos**

# %%
fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %% [markdown]
# ___

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return f"{pct:.1f}%\n({absolute:d} g)"


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()
